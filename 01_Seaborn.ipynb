# %% [markdown]
# # Seaborn

# %%
# pip install seaborn

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Load Seaborn Datasets

# %%
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
z = [0.5, 1, 1.5, 2, 2.5]


# 1. create a line plot 
sns.lineplot(x=x, y=y, color='r', linewidth = 2, linestyle = '--')
sns.lineplot(x=x, y=x, color='g', linewidth = 2, linestyle = '--')
#plt.plot(df['X'], df['y'])

# 2. configure the plot 
plt.legend(['profit1', 'profit2'])
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('My first seaborn line plot')

# 3. save the plot 
plt.savefig('./exports/lineplot4.png')

# 4. display plot
plt.show()

# %%
# load the flights data set
flights = sns.load_dataset('flights')

# use pivot to restructure the flights table
flights_pivot = flights.pivot(index = 'year', columns = 'month', values = 'passengers')


flights_pivot.head(10)

# Line plot 
sns.lineplot(data = flights_pivot['Apr'])
# Out:
# <Axes: xlabel='year', ylabel='Apr'>

# %%
# Line plot 
# create a line plot for each month
sns.lineplot(data=flights, x='year', y='passengers', color='r', hue='month')

# aggregate and plot the meanvalue with 95% confidence interval
sns.lineplot(data = flights, x = 'year', y = 'passengers', color = 'r')

plt.xticks(rotation = 30)
plt.yticks(rotation = 30)
plt.show()

# %%
# Plot each year's time series in its own facet
g = sns.relplot(
    data=flights,
    x="month", y="passengers", col="year", hue="year",
    kind="line", palette="crest", linewidth=4, zorder=5,
    col_wrap=3, height=2, aspect=1.5, legend=False,
)

# Iterate over each subplot to customize further
for year, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(.8, .85, year, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=flights, x="month", y="passengers", units="year",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )

# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[::2])

# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("", "Passengers")
g.tight_layout()

# %% [markdown]
# # Bar Plot

# %%
x = ['A', 'B', 'C', 'D']
y = [3,8,1,10]

sns.barplot(x=x, y=y)
# Out:
# <Axes: >

# %%
experience = [1,2,3,4,5,6,7,8]
data_scientists_salary = [65000, 92000, 126570, 400000, 900000, 657538, 890000, 500000]
genders = ['Men', 'Women', 'Men', 'Women', 'Men', 'Men', 'Women', 'Men']

sns.barplot(x=experience, y = data_scientists_salary, hue = genders)
#sns.pointplot(x=experience, y=data_scientists_salary)

sns.lineplot(x=experience, y=data_scientists_salary, marker = '*')

#sns.barplot(x=experience, y = data_scientists_salary, hue = genders, orient = 'h')
# Out:
# <Axes: >

# %% [markdown]
# # Pair Plot
# ## Kernel Density Esimation
# Die Kerndichteschätzung ist ein statistisches Verfahren zur Schätzung der Wahrscheinlichkeitsverteilung einer Zufallsvariablen. In der klassischen Statistik geht man davon aus, dass statistische Phänomene einer bestimmten Wahrscheinlichkeitsverteilung folgen und dass sich diese Verteilung in Stichproben realisiert.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 73            6.1          2.8           4.7          1.2  versicolor
# 18            5.7          3.8           1.7          0.3      setosa
# 118           7.7          2.6           6.9          2.3   virginica
# 78            6.0          2.9           4.5          1.5  versicolor
# 76            6.8          2.8           4.8          1.4  versicolor
# 31            5.4          3.4           1.5          0.4      setosa
# 64            5.6          2.9           3.6          1.3  versicolor
# 141           6.9          3.1           5.1          2.3   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor

# %%
sns.pairplot(iris, hue='species', kind='scatter')

# %%
import seaborn as sns
sns.pairplot(iris, hue='species', kind='kde')

# %% [markdown]
# # Box Plot

# %%
import numpy as np
np.random.seed(42)
print(iris.columns)
sns.boxplot(x='sepal_length', data=iris)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# <Axes: xlabel='sepal_length'>

# %%
import seaborn as sns

# Liste aller verfügbaren Datensätze in Seaborn
dataset_list = sns.get_dataset_names()

import pandas as pd
pd.DataFrame(dataset_list, columns=['Datasets_names'])
#print(dataset_list)
# Out:
#     Datasets_names
# 0         anagrams
# 1         anscombe
# 2        attention
# 3   brain_networks
# 4      car_crashes
# 5         diamonds
# 6             dots
# 7         dowjones
# 8         exercise
# 9          flights
# 10            fmri
# 11          geyser
# 12            glue
# 13       healthexp
# 14            iris
# 15             mpg
# 16        penguins
# 17         planets
# 18          seaice
# 19           taxis
# 20            tips
# 21         titanic

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(flights_pivot)
# Out:
# <Axes: xlabel='month', ylabel='year'>
